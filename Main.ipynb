# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("BAJFINANCE.NS (4).csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4995 entries, 0 to 4994
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4995 non-null   object
#  1   Open       4985 non-null   float64
#  2   High       4985 non-null   float64
#  3   Low        4985 non-null   float64
#  4   Close      4985 non-null   float64
#  5   Adj Close  4985 non-null   float64
#  6   Volume     4985 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 273.3+ KB

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0     02-07-02     5.523439     5.537041     5.421423     5.443769
# 1     03-07-02     5.505950     5.545785     5.328151     5.466116
# 2     04-07-02     5.501093     5.572018     5.417537     5.528297
# 3     05-07-02     5.563274     5.656546     5.474860     5.590478
# 4     08-07-02     5.501093     5.718727     5.501093     5.625455
# ...        ...          ...          ...          ...          ...
# 4990  18-07-22  5969.899902  6068.100098  5931.350098  6059.799805
# 4991  19-07-22  6040.000000  6098.149902  6002.049805  6065.950195
# 4992  20-07-22  6149.000000  6149.600098  6042.049805  6074.399902
# 4993  21-07-22  6079.000000  6283.149902  6036.000000  6266.899902
# 4994  22-07-22  6271.000000  6325.000000  6217.700195  6258.250000
#
#         Adj Close     Volume
# 0        4.009640    61044.0
# 1        4.026099    34160.0
# 2        4.071899    27892.0
# 3        4.117700    58976.0
# ...

# %%
value=df.sort_values(by="Close",ascending=False)
y=value["Close"][:10].reset_index(drop=True)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')
z=df["Date"][:10].reset_index(drop=True)
z
# Out:
# 0   2002-07-02
# 1   2002-07-03
# 2   2002-07-04
# 3   2002-07-05
# 4   2002-07-08
# 5   2002-07-09
# 6   2002-07-10
# 7   2002-07-11
# 8   2002-07-12
# 9   2002-07-15
# Name: Date, dtype: datetime64[ns]

# %%
df['year']=df ["Date"].dt.year
yearly_data = df.groupby('year')['Close'].mean()
yearly_data
# Out:
# year
# 2002       4.476779
# 2003       5.451534
# 2004       8.348823
# 2005      24.161243
# 2006      38.669673
# 2007      36.960380
# 2008      21.180767
# 2009      16.382539
# 2010      52.059868
# 2011      62.920055
# 2012      95.814011
# 2013     130.659036
# 2014     220.726291
# 2015     478.995183
# 2016     829.154695
# 2017    1464.045563
# 2018    2183.707524
# 2019    3361.149799
# 2020    3501.387450
# 2021    6231.373775
# 2022    6559.567987
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt
years = [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
values = [4.476779, 5.451534, 8.348823, 24.161243, 38.669673, 36.960380, 21.180767, 16.382539, 52.059868, 62.920055, 95.814011, 130.659036, 220.726291, 478.995183, 829.154695, 1464.045563, 2183.707524, 3361.149799, 3501.387450, 6231.373775, 6559.567987]
plt.hist(years, bins=range(2002, 2023), weights=values, rwidth=0.8, edgecolor='black')
plt.xlabel('Year')
plt.ylabel('Close Values')
plt.title('Year Vs Closing Prize')
plt.show()

# %%
df['year']=df["Date"].dt.year
yearly_high = df.groupby('year')['High'].mean()
yearly_high
# Out:
# year
# 2002       4.543959
# 2003       5.586001
# 2004       8.527508
# 2005      24.606907
# 2006      39.639299
# 2007      37.793060
# 2008      22.085937
# 2009      16.934441
# 2010      53.195880
# 2011      64.208427
# 2012      97.327874
# 2013     133.112651
# 2014     224.416598
# 2015     486.511789
# 2016     843.770469
# 2017    1483.900403
# 2018    2216.792065
# 2019    3402.646496
# 2020    3571.643624
# 2021    6322.498200
# 2022    6654.794268
# Name: High, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a DataFrame from the data
data = {
    'Year': [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'High': [4.543959, 5.586001, 8.527508, 24.606907, 39.639299, 37.793060, 22.085937, 16.934441, 53.195880, 64.208427, 97.327874, 133.112651, 224.416598, 486.511789, 843.770469, 1483.900403, 2216.792065, 3402.646496, 3571.643624, 6322.498200, 6654.794268]
}
dff = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
plt.boxplot(dff['High'], vert=False)
plt.xlabel('High Value')
plt.title('Box Plot of High Values Over the Years')
plt.show()

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# Date          0
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# year          0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
columns_to_impute = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
imputer = SimpleImputer(strategy='mean')
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2002-07-02     5.523439     5.537041     5.421423     5.443769
# 1    2002-07-03     5.505950     5.545785     5.328151     5.466116
# 2    2002-07-04     5.501093     5.572018     5.417537     5.528297
# 3    2002-07-05     5.563274     5.656546     5.474860     5.590478
# 4    2002-07-08     5.501093     5.718727     5.501093     5.625455
# ...         ...          ...          ...          ...          ...
# 4990 2022-07-18  5969.899902  6068.100098  5931.350098  6059.799805
# 4991 2022-07-19  6040.000000  6098.149902  6002.049805  6065.950195
# 4992 2022-07-20  6149.000000  6149.600098  6042.049805  6074.399902
# 4993 2022-07-21  6079.000000  6283.149902  6036.000000  6266.899902
# 4994 2022-07-22  6271.000000  6325.000000  6217.700195  6258.250000
#
#         Adj Close     Volume  year
# 0        4.009640    61044.0  2002
# 1        4.026099    34160.0  2002
# 2        4.071899    27892.0  2002
# ...

# %%
df['profit']=df['Close']-df['Open']
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2002-07-02     5.523439     5.537041     5.421423     5.443769
# 1    2002-07-03     5.505950     5.545785     5.328151     5.466116
# 2    2002-07-04     5.501093     5.572018     5.417537     5.528297
# 3    2002-07-05     5.563274     5.656546     5.474860     5.590478
# 4    2002-07-08     5.501093     5.718727     5.501093     5.625455
# ...         ...          ...          ...          ...          ...
# 4990 2022-07-18  5969.899902  6068.100098  5931.350098  6059.799805
# 4991 2022-07-19  6040.000000  6098.149902  6002.049805  6065.950195
# 4992 2022-07-20  6149.000000  6149.600098  6042.049805  6074.399902
# 4993 2022-07-21  6079.000000  6283.149902  6036.000000  6266.899902
# 4994 2022-07-22  6271.000000  6325.000000  6217.700195  6258.250000
#
#         Adj Close     Volume  year      profit
# 0        4.009640    61044.0  2002   -0.079670
# 1        4.026099    34160.0  2002   -0.039834
# ...

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
x= df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'year']]
y= df['profit'].to_list()
scaler = StandardScaler()
x = scaler.fit_transform(x)
svr = SVR(kernel='linear', C=1.0)
svr.fit(x,y)
y_pred = svr.predict(x)

# %%
s = [32, 35,10,56,554,40.33, 2024] 
s = scaler.transform([s])
predicted_profit = svr.predict(s)
print(f"Predicted Profit: {predicted_profit[0]}")
# Out:
# Predicted Profit: 4.784000097877549
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', label='Actual')
plt.scatter(x, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('SVR - Actual vs. Predicted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/vyakaranamsowmya/Desktop/Quants/Main.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/Users/vyakaranamsowmya/Desktop/Quants/Main.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 6))
# ----> <a href='vscode-notebook-cell:/Users/vyakaranamsowmya/Desktop/Quants/Main.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> plt.scatter(x, y, color='blue', label='Actual')
#       <a href='vscode-notebook-cell:/Users/vyakaranamsowmya/Desktop/Quants/Main.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> plt.scatter(x, y_pred, color='red', label='Predicted')
#       <a href='vscode-notebook-cell:/Users/vyakaranamsowmya/Desktop/Quants/Main.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('X')
#
# ...

# %%
print(x)
# Out:
# [[-0.58574345 -0.58642645 -0.58502068 ... -0.58425923 -0.43799317
#   -1.70741895]
#  [-0.58575269 -0.58642189 -0.58507071 ... -0.58425049 -0.45140863
#   -1.70741895]
#  [-0.58575525 -0.58640822 -0.58502276 ... -0.58422617 -0.45453644
#   -1.70741895]
#  ...
#  [ 2.65967834  2.61569461  2.65263941 ...  2.63890255 -0.05572548
#    1.71963146]
#  [ 2.62269935  2.68529719  2.64939468 ...  2.74111322  0.19298295
#    1.71963146]
#  [ 2.72412743  2.70710834  2.74684701 ...  2.73652042  0.00725142
#    1.71963146]]

# %%
print(y)
# Out:
#           profit
# 0      -0.079670
# 1      -0.039834
# 2       0.027204
# 3       0.027204
# 4       0.124362
# ...          ...
# 4990   89.899903
# 4991   25.950195
# 4992  -74.600098
# 4993  187.899902
# 4994  -12.750000
#
# [4995 rows x 1 columns]
